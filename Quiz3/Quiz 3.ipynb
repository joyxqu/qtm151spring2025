# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 3 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here
print('Joy Qu')
# Out:
# Joy Qu

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:
print('I will abide by Emory\'s code of conduct')
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy" and "pandas"

# %%
# Write your answer here
# Import the numpy library
import numpy as np

# Import the pandas library
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# (a) Replace the values of a column
#
# <font size = "3">
#
# - Import the "data_raw/constructors.csv" file
# - Replace the values "British", "Japanese", and "Irish" with <br>
# "UK", "Japan", "Ireland" in the column "nationality"
#
#
# HINT: See the example in Lecture 12

# %%
# Write your own code
# Read the constructors dataset
constructors = pd.read_csv('data_raw/constructors.csv')

# List the old values being replaced
list_old = ['British','Japanese', 'Irish']

# List the new values replacing the old
list_new = ['UK', 'Japan', 'Ireland']

# Replace the 'nationality' values
constructors['nationality'] = constructors['nationality'].replace(list_old, list_new)

# Print the 'nationality' column
print(constructors['nationality'])
# Out:
# 0            UK
# 1        German
# 2            UK
# 3        French
# 4       Italian
#          ...
# 206          UK
# 207    American
# 208          UK
# 209     Italian
# 210      French
# Name: nationality, Length: 211, dtype: object

# %% [markdown]
# <font size = "5">
#
# (b) Aggregate and query
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" file
# - Subset the observations for 'constructorId == 3' using ```.query()```
# - Obtain the maximum of "laps" by "driverId" <br>
#  using ``` .groupby().agg() ```
# - Subset the drivers with a maximum of laps $\ge 10$
# - Store the results of all these operations in a dataframe <br>
# ```sprint_results_agg ```

# %%
# Write your own code
# Read the sprints dataset
sprints = pd.read_csv('data_raw/sprint_results.csv')

# Subset the data for 'constructorId = 3'
subset = sprints.query("constructorId == 3")

# Group the data by 'driverId'
sprint_results_agg = (subset.groupby('driverId')
                      
# Calculate the maximum laps
                      .agg(max_laps = ('laps', 'max'))

# Subset the data for 'max_laps >= 10'
                      .query('max_laps >= 10'))

# Print the 'sprint_results_agg' column
print(sprint_results_agg)
# Out:
#           max_laps
# driverId
# 847             24
# 848             23
# 849             24

# %% [markdown]
# <font size = "5">
#
# (c) Recode a numeric colum
#
# <font size = "3">
#
# - Import the "data_raw/races.csv" file
# - Recode the "year" column into a new column "year_brackets" <br>
# with the following categories
#
# $\qquad$ ``` ["1950-1965","1966-1980","1980-onwards"] ```
#
# $\qquad$ HINT: Use the "pd.cut()" command.

# %%
# Write your own code
# Read the races dataset
races = pd.read_csv('data_raw/races.csv')

# Define the bins and labels
bins_x = [1949, 1965, 1980, float("inf")]
labels_x = ['1950-1965', '1966-1980', '1981-onwards']

# Create a new column 'year_brackets'
# Categorize the 'year' column based on the bins
races['year_brackets'] = pd.cut(races['year'],
                              bins = bins_x,
                              right = True,
                              labels = labels_x)

# Print the 'year' and categorized 'year_brackets' column
print(races[['year', 'year_brackets']])
# Out:
#       year year_brackets
# 0     2009  1981-onwards
# 1     2009  1981-onwards
# 2     2009  1981-onwards
# 3     2009  1981-onwards
# 4     2009  1981-onwards
# ...    ...           ...
# 1097  2023  1981-onwards
# 1098  2023  1981-onwards
# 1099  2023  1981-onwards
# 1100  2023  1981-onwards
# 1101  2023  1981-onwards
#
# [1102 rows x 2 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Aggregate and sort
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" file
# - Obtain the maximum of "laps" by "driverId" <br>
# using ``` .groupby().agg() ```
# - Sort the teams in descending order using of <br>
# the maximum of laps using ``` .sort_values() ```

# %%
# Write your own code
# Read the sprints dataset
sprints = pd.read_csv('data_raw/sprint_results.csv')

# Group the data by 'driverId'
(sprints.groupby('driverId')
 
# Calculate the maximum laps
        .agg(max_laps = ('laps', 'max'))

# Sort the results by 'max_laps'
        .sort_values(by = 'max_laps', ascending = False))
# Out:
#           max_laps
# driverId
# 1               24
# 4               24
# 854             24
# 853             24
# 852             24
# 849             24
# 847             24
# 846             24
# 844             24
# 842             24
# 841             24
# 840             24
# 839             24
# 832             24
# 830             24
# 825             24
# 822             24
# 817             24
# 815             24
# 20              24
# 8               24
# 855             24
# 848             23
# 9               18

# %% [markdown]
# <font size = "5">
#
# (e) Rename column
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" file
# - Rename the column "time" to "time_unformatted"
#
# HINT: Create a dictionary and use ```.rename(columns = ...)``` <br>
# See Lecture 15

# %%
# Write your own code
# Read the sprints dataset
sprints_raw = pd.read_csv('data_raw/sprint_results.csv')

# Rename the 'sprints_raw' 'time' column
sprints = sprints_raw.rename(columns={'time':'time_unformatted'})

# Print the 'sprints_raw' data columns
print(f'Old List: {sprints_raw.columns.values}')
print('')

# Print the 'sprints' data columns
print(f'New List: {sprints.columns.values}')
# Out:
# Old List: ['resultId' 'raceId' 'driverId' 'constructorId' 'number' 'grid' 'position'
#  'positionText' 'positionOrder' 'points' 'laps' 'time' 'milliseconds'
#  'fastestLap' 'fastestLapTime' 'statusId']
#
# New List: ['resultId' 'raceId' 'driverId' 'constructorId' 'number' 'grid' 'position'
#  'positionText' 'positionOrder' 'points' 'laps' 'time_unformatted'
#  'milliseconds' 'fastestLap' 'fastestLapTime' 'statusId']

# %% [markdown]
# <font size = "5">
#
# (f) Merge dataset
#
# <font size = "3">
#
# - Import the "data_raw/sprint_results.csv" and <br>
# "data_raw/constructors.csv" files
# - Create a new dataset with  ```pd.merge()``` using <br>
# "sprint_results" as the primary dataset, and <br>
# "constructors" as the secondary dataset, merging on <br>
# the column "constructorId"
# - To get full points **ONLY** merge the "nationality" column <br>
# from the secondary dataset (not all the columns)
#
# HINT: Use ```[[...]]``` to extract a subset of columns <br>
# from the secondary dataset before merging, including the <br>
# "constructorId" column

# %%
# Write your own code
# Read the sprints dataset
sprint_results = pd.read_csv('data_raw/sprint_results.csv')

# Read the constructors dataset
constructors = pd.read_csv('data_raw/constructors.csv')

# Merge the 'sprint_results' and 'constructors' subset data
sprints_constructors = pd.merge(sprint_results, 
                                constructors[['nationality', 'constructorId']], 
                                
# Merge on the 'constructorId' column
                                on = 'constructorId', 

# Merge left on 'sprint_results'
                                how = 'left')

# Print the 'sprints_constructors' data
sprints_constructors
# Out:
#      resultId  raceId  driverId  constructorId  number  grid position  \
# 0           1    1061       830              9      33     2        1
# 1           2    1061         1            131      44     1        2
# 2           3    1061       822            131      77     3        3
# 3           4    1061       844              6      16     4        4
# 4           5    1061       846              1       4     6        5
# ..        ...     ...       ...            ...     ...   ...      ...
# 115       116    1095       840            117      18    15       16
# 116       117    1095       839            214      31     6       17
# 117       118    1095         4            214      14     7       18
# 118       119    1095       849              3       6    16       19
# 119       120    1095       848              3      23    11       \N
#
#     positionText  positionOrder  points  laps       time milliseconds  \
# ...
